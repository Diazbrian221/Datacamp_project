# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
Salaries_df = pd.read_csv("/home/brian/Downloads/d_science/ds_salaries.csv")
type(Salaries_df)
df = pd.concat(map(pd.read_csv, ["/home/brian/Downloads/d_science/ds_salaries.csv"
                                , "/home/brian/Downloads/d_science/Stores.csv"]))
type(df)
job_types = ['Data Scientist', 'Data Engineer']

filt = (df["job_title"].isin(job_types))

# %%
ax = sns.violinplot(x = "job_title", y = "salary_in_usd", data=df.loc[filt]
                   ,scale = "count")

# %%
Stores_df = pd.read_csv("/home/brian/Downloads/d_science/Stores.csv")
type(Stores_df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0           0.0     2020.0               MI              FT
# 1           1.0     2020.0               SE              FT
# 2           2.0     2020.0               SE              FT
# 3           3.0     2020.0               MI              FT
# 4           4.0     2020.0               SE              FT
# ..          ...        ...              ...             ...
# 891         NaN        NaN              NaN             NaN
# 892         NaN        NaN              NaN             NaN
# 893         NaN        NaN              NaN             NaN
# 894         NaN        NaN              NaN             NaN
# 895         NaN        NaN              NaN             NaN
#
#                       job_title    salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000.0             EUR        79833.0
# 1    Machine Learning Scientist  260000.0             USD       260000.0
# ...

# %%
Stores_df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
Salaries_df.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
ax = sns.barplot(x = "Daily_Customer_Count", y = "Store_Sales", data = Stores_df.head(5)
                )

# %%
sns.displot(Salaries_df, x='experience_level')
